# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavmaheshwari75-commits/-E-Commerce-Customer-Retention-RFM-Segmentation/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Using Python script as a calculator
# Create the variables n, r, p and assign them values 10, 5, and 100 respectively. Then evaluate the following expression in the Python console:
# A=p(1+r/100) n$0

# %%
# Code Solution:
n = 10
r = 5
p = 100

A = p * (1 + r / 100) ** n
print(round(A, 2))  # Output: 162.89
# Out:
# 162.89
